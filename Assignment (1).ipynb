# %%
l1 = [1,2,3,4]
l2 = [3,4,5,6]
#add this two list elementwise
add = [a+b for a,b in zip(l1,l2)]
print(add)
# Out:
# [4, 6, 8, 10]

# %%
#Find maximum element combining two list l1 and l2
l1 = [1,2,3,4]
l2 = [3,4,5,6]
combined_list = l1+l2
max_element=max (combined_list)
print(max_element)
# Out:
# 6

# %%
#find common elemnts from list l1 and l2
l1 = [1,2,3,4]
l2 = [3,4,5,6]
common_elements = (set(l1) & set(l2))
print(f"common_elements:{common_elements}")
# Out:
# common_elements:{3, 4}

# %%
d1 = {'a': 1, 'b': 2, 'c': 3, 'd': 4}
d2 = {'a': 7, 'f': 2, 'g': 55, 'h': "101"}

#find common key from d1 and d2
#find common value from d1 and d2
common_elements = d1.keys() & d2.keys()
print(common_elements)
common_elements = d1.values() & d2.values()
print(common_elements)
# Out:
# {'a'}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-0d84eea9d6b4> in <cell line: 8>()
#       6 common_elements = d1.keys() & d2.keys()
#       7 print(common_elements)
# ----> 8 common_elements = d1.values() & d2.values()
#       9 print(common_elements)
#
# TypeError: unsupported operand type(s) for &: 'dict_values' and 'dict_values'

# %%
#replace the values of d1 to their negatie value
d1 = {'a': 1, 'b': 2, 'c': 3, 'd': 4}
replaced_values = (key:-value for key,value in d1)

# %%
#replace key to value and value to key in d2
